# %%
from optibook.synchronous_client import Exchange

import time
import logging
logger = logging.getLogger("client")
logger.setLevel("ERROR")
print("Setup was successful.")
# Out:
# Setup was successful.
# kj/filesystem-disk-unix.c++:1734: warning: PWD environment variable doesn't match current directory; pwd = /opt

# %%
from plot_nvda_dual_prices import plot_nvda_pair

# %%
plot_nvda_pair()
# Out:
# usage: ipykernel_launcher.py [-h] [--data-dir DATA_DIR] [--template TEMPLATE]
#                              [--save SAVE]
# ipykernel_launcher.py: error: unrecognized arguments: --f=/home/workspace/.local/share/jupyter/runtime/kernel-v3c54913fe2112aec36d3642730f5c57aef248c986.json
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2
# /usr/local/lib/python3.10/site-packages/IPython/core/interactiveshell.py:3587: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
