# %%
from pathlib import Path
import sys

for _repo in [Path.cwd(), *Path.cwd().parents]:
    if (_repo / "data" / "plotting.py").is_file():
        if str(_repo) not in sys.path:
            sys.path.insert(0, str(_repo))
        break
else:
    raise RuntimeError("Could not find repo root containing data/plotting.py")

from data.plotting import plot_ob5x_index_theory, plot_dual_pairs

# %%
plot_dual_pairs(n=1000)

# %%
plot_ob5x_index_theory(n=200)
